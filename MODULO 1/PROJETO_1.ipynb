# %% [markdown]
# <a href="https://colab.research.google.com/github/89CANDY89/BOOTCAMP-2-ALURA/blob/main/MODULO%201/PROJETO_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROJETO FINAL E DESAFIO
#
# Escolha outro valor fora o valor aprovado no TABNET e explore estes dados. Esse será nosso projeto do módulo, mais detalhes no Desafio do módulo 1 na página do bootcamp.

# %% [markdown]
# ![SUSUS.png](data:image/png;base64,...)

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
pd.options.display.float_format = '{:.2f}'.format

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/89CANDY89/BOOTCAMP-2-ALURA/main/dados/COVID%20DADOS.csv", encoding='ISO-8859-1', skiprows=0, sep = ';', skipfooter=12, thousands='.', decimal=',', engine='python')

# %% [markdown]
# ## Coleta de dados

# %% [markdown]
# Dados
# https://opendatasus.saude.gov.br/pt_BR/dataset/dados-covid/resource/77d8d14a-cf8c-4209-bed3-3b63ed63fd4f

# %%
dados.head()
# Out:
#    regiao  coduf  ... emAcompanhamentoNovos  interior/metropolitana
# 0  Brasil     76  ...                   nan                     nan
# 1  Brasil     76  ...                   nan                     nan
# 2  Brasil     76  ...                   nan                     nan
# 3  Brasil     76  ...                   nan                     nan
# 4  Brasil     76  ...                   nan                     nan
#
# [5 rows x 12 columns]

# %% [markdown]
# ## ANALISE

# %%
usaveis = dados.mean().index.tolist()
usaveis.insert(0, 'data')
dados_usaveis = dados[usaveis]
dados_usaveis = dados_usaveis.set_index('data')
dados_usaveis = dados_usaveis.drop(['populacaoTCU2019','coduf', 'interior/metropolitana','semanaEpi','casosNovos', 'obitosAcumulado',
       'obitosNovos','emAcompanhamentoNovos'], axis=1)


obitos = dados.mean().index.tolist()
obitos.insert(0, 'data')
dados_obitos = dados[obitos]
dados_obitos = dados_obitos.set_index('data')
dados_obitos = dados_obitos.drop(['populacaoTCU2019','coduf', 'interior/metropolitana','semanaEpi', 'casosAcumulado','Recuperadosnovos', 'emAcompanhamentoNovos', 'obitosAcumulado'], axis=1)

# %%
dados_usaveis.columns
# Out:
# Index(['casosAcumulado', 'Recuperadosnovos'], dtype='object')

# %%
dados_obitos.columns
# Out:
# Index(['casosNovos', 'obitosAcumulado'], dtype='object')

# %%
fig, axs = plt.subplots(1,2, figsize=(20,8))

dados_obitos.plot(grid=True, ax=axs[1])

dados_usaveis.plot(grid=True, ax=axs[0])

axs[0].set_title('CASOS ACUMULADOS E RECUPERADOS')
axs[0].set_xlabel('DATA')
axs[0].set_ylabel('QUANTIDADE DE PESSOAS')

axs[1].set_title('OBITOS ACUMULADOS E NOVOS CASOS')
axs[1].set_xlabel('DATA')
axs[1].set_ylabel('QUANTIDADE DE PESSOAS')

plt.ylim(3,8)
plt.suptitle('GRAFICOS DE CASOS ACUMULADOS E DE OBITOS', fontsize=18)

plt.show()

# %%
dados_obitos.plot(figsize=(12,8))

# %% [markdown]
# ## RESULTADO

# %% [markdown]
# Com base nos graficos é possivel ver uma elevada capacidade de recuperação dos pacientes devido a pandemia de Coronavirus.
#
# O percentual de casos novos chegou em uma terceira onda de subida. Com isso os obtidos tendem a seguir a mesma regra como observado nos graficos acima
